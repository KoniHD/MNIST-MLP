# %% [markdown]
# # Setup

# %%
# !uv sync
# Out:
# Resolved 113 packages in 13ms
# Checked 90 packages in 13ms

# %%
import argparse
from mnist_pytorch.train import main as train
from mnist_pytorch.evaluate import main as eval

# %% [markdown]
# # Training

# %%
hyps = argparse.Namespace(
    epochs=10,
    batch_size=128,
    learning_rate=0.1,
    weights_path="../../models/model_weights",
    plot=True,
)

train(hyps)
# Out:
# Using device: mps
# Using Batch size: 128
# Epoch [1/10]: 100%|██████████| 469/469 [00:02<00:00, 163.85it/s, loss=0.3056]
# Epoch [1/10] Completed | Avg Loss 0.5633
# Epoch [2/10]: 100%|██████████| 469/469 [00:02<00:00, 171.74it/s, loss=0.1278]
# Epoch [2/10] Completed | Avg Loss 0.2857
# Epoch [3/10]: 100%|██████████| 469/469 [00:02<00:00, 171.34it/s, loss=0.1403]
# Epoch [3/10] Completed | Avg Loss 0.2330
# Epoch [4/10]: 100%|██████████| 469/469 [00:02<00:00, 159.20it/s, loss=0.1389]
# Epoch [4/10] Completed | Avg Loss 0.1963
# Epoch [5/10]: 100%|██████████| 469/469 [00:02<00:00, 166.69it/s, loss=0.2393]
# Epoch [5/10] Completed | Avg Loss 0.1690
# Epoch [6/10]: 100%|██████████| 469/469 [00:02<00:00, 178.45it/s, loss=0.1734]
# Epoch [6/10] Completed | Avg Loss 0.1478
# Epoch [7/10]: 100%|██████████| 469/469 [00:02<00:00, 172.72it/s, loss=0.0686]
# Epoch [7/10] Completed | Avg Loss 0.1312
# Epoch [8/10]: 100%|██████████| 469/469 [00:02<00:00, 186.63it/s, loss=0.1016]
# ...

# %%
# !uv run mnist-pytorch evaluate --plot
args = argparse.Namespace(
    batch_size=128, plot=True, weights_path="../models/model_weights"
)

eval(args)
# Out:
# Using dvice: mps
# Testing on test dataset: 100%|██████████| 79/79 [00:00<00:00, 194.38it/s]
# Test Accuracy: 0.9704 (97.04%)
# Generating prediction visualization grid...
